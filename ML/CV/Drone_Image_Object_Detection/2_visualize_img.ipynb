# %% [markdown]
# Автор: Лейман М.А.
# Дата создания: 13.06.2025

# %% [markdown]
# # Визуализация изображений с боксами

# %%
from utils.preprocess import find_images_with_class
from utils.visualize_img import visualize_img, visualize_img_full
import os

# %%
target_path = "target/"
images_path = "images/"

# Получаем текущую рабочую папку  
current_directory = os.getcwd()  
path_dataset = os.path.join(current_directory, "data/dataset")
label_dir = os.path.join(path_dataset, target_path)  
images_dir = os.path.join(path_dataset, images_path)  

find_images_with_class(label_dir, target_class=0)
# Out:
# ['1.jpg', '2.jpg']

# %% [markdown]
# ### Просмотр.  Обработка датасета. Исправление разметки.
#
# ![image.png](attachment:image.png)
#
# #### НЕ весь датасет размечен корректно

# %%
image_name = "1.jpg"  

images_path=images_dir
labels_path=label_dir
visualize_img(image_name, images_path=images_path, labels_path=labels_path)
# Out:
# /home/maksim/develops/python/Zala_task/Zala_task/data/dataset/images/1.jpg
# /home/maksim/develops/python/Zala_task/Zala_task/data/dataset/target/1.txt

# %% [markdown]
# ## Просмотр изображений в цикле

# %%
images_path=images_dir
labels_path=label_dir

visualize_img_full(images_path=images_path, labels_path=labels_path, size_x = 12, size_y=12)
# Out:
# 2.jpg
# /home/maksim/develops/python/Zala_task/Zala_task/data/dataset/images/2.jpg
# /home/maksim/develops/python/Zala_task/Zala_task/data/dataset/target/2.txt
# Все изображения проверены!
